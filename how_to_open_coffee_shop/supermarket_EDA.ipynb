# %% [markdown]
# Location Intelligence

# %% [markdown]
# https://www.nea.gov.sg/our-services/food-hygiene/licensing-permits/food-retail-industry/food-shop-licence

# %% [markdown]
# https://data.gov.sg/dataset/list-of-supermarket-licences?view_id=aa6bfba1-afbb-4932-b973-b1bc1c4bbf20&resource_id=3561a136-4ee4-4029-a5cd-ddf591cce643

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import folium
import matplotlib as mpl

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
csv = "data\list-of-supermarket-licences.csv"
df = pd.read_csv(csv)
df.head()

# %%
len(df.licensee_name.unique())

# %%
df2 = df.groupby(df.licensee_name).count().sort_values(by="licence_num",ascending=False)
df2.head()
# Out:
#                                        licence_num  building_name  \
# licensee_name
# NTUC Fairprice Co-operative Ltd                133            133
# COLD STORAGE SINGAPORE (1983) PTE LTD          111            111
# SHENG SIONG SUPERMARKET PTE LTD                 42             42
# PRIME SUPERMARKET LIMITED?                      10             10
# PRIME SUPERMARKET (1996) PTE LTD                 8              8
#
#                                        block_house_num  level_num  unit_num  \
# licensee_name
# NTUC Fairprice Co-operative Ltd                    133        133       133
# COLD STORAGE SINGAPORE (1983) PTE LTD              111        111       111
# SHENG SIONG SUPERMARKET PTE LTD                     42         42        42
# PRIME SUPERMARKET LIMITED?                          10         10        10
# PRIME SUPERMARKET (1996) PTE LTD                     8          8         8
#
#                                        street_name  postal_code
# licensee_name
# NTUC Fairprice Co-operative Ltd                133          133
# COLD STORAGE SINGAPORE (1983) PTE LTD          111          111
# SHENG SIONG SUPERMARKET PTE LTD                 42           42
# PRIME SUPERMARKET LIMITED?                      10           10
# PRIME SUPERMARKET (1996) PTE LTD                 8            8

# %%
df_unique_companies = df.groupby(df.licensee_name).size().sort_values(ascending=False)

# df_unique_companies.reset_index()

names = df_unique_companies.keys()
count = df_unique_companies.tolist()

names[:5]
# Out:
# Index(['NTUC Fairprice Co-operative Ltd',
#        'COLD STORAGE SINGAPORE (1983) PTE LTD',
#        'SHENG SIONG SUPERMARKET PTE LTD', 'PRIME SUPERMARKET LIMITED?',
#        'PRIME SUPERMARKET (1996) PTE LTD'],
#       dtype='object', name='licensee_name')

# %%
# plt.figure(figsize=(20,20))
# fig = sns.barplot(y=names,x=count)

# %%
df3 = df.copy()

# %%
top5 = list(df_unique_companies.head().keys())

# %%
group_list = []

for i in range(len(df)):
    if df.iloc[i].licensee_name in top5:
        groupID = top5.index(df.iloc[i].licensee_name)
    else:
        groupID = -1
    group_list.append(groupID)

# group_list[:10]

df3['group'] = group_list
df3
# Out:
#      licence_num                               licensee_name  \
# 0     S02185J000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 1     S97166P000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 2    CE15B61K000               U STARS SUPERMARKET PTE. LTD.
# 3     S02029J000             NTUC Fairprice Co-operative Ltd
# 4    CE04561V000             SHENG SIONG SUPERMARKET PTE LTD
# 5    CE14L50J000             NTUC Fairprice Co-operative Ltd
# 6    CE12H94B000            PRIME SUPERMARKET (1996) PTE LTD
# 7    CE16913J000             SHENG SIONG SUPERMARKET PTE LTD
# 8    CE15042P000                 D-RON INVESTMENTS PTE. LTD.
# 9    CE15023A000                         GW TRADER PTE. LTD.
# 10   CE11N78X000                            HONG AIK PTE LTD
# 11   NE11909C000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 12    S02027L000             NTUC Fairprice Co-operative Ltd
# 13   CE13R25C000             NTUC Fairprice Co-operative Ltd
# 14   CE13S05E000                 LABIBA ENTERPRISE PTE. LTD.
# 15    S93171X000                  ANG MO SUPERMARKET PTE LTD
# 16   CE06M36N000             NTUC Fairprice Co-operative Ltd
# 17   CE12J32X000             NTUC Fairprice Co-operative Ltd
# 18   CE11P32L000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 19   CE11N90C000             NTUC Fairprice Co-operative Ltd
# 20    S02169J000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 21    B98014C000             NTUC Fairprice Co-operative Ltd
# 22    B02015J000             SHENG SIONG SUPERMARKET PTE LTD
# 23   CE05096V000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 24   CE04334P000             SHENG SIONG SUPERMARKET PTE LTD
# 25   CE13401C000                           G8 MART PTE. LTD.
# 26    S02021B000             NTUC Fairprice Co-operative Ltd
# 27    S02023V000             NTUC Fairprice Co-operative Ltd
# 28   CE09512V000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 29    S94081C000             NTUC Fairprice Co-operative Ltd
# ..           ...                                         ...
# 448  SW04097K000                  PRIME SUPERMARKET LIMITED?
# 449   C02046K000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 450   C02104B000             NTUC Fairprice Co-operative Ltd
# 451  SW13126K000                      BALU MINIMART PTE. LTD
# 452  SW08821N000             NTUC Fairprice Co-operative Ltd
# 453   J02021A000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 454   J02020B000            PRIME SUPERMARKET (1996) PTE LTD
# 455   J02017N000                  PRIME SUPERMARKET LIMITED?
# 456  SW11423N000             SHENG SIONG SUPERMARKET PTE LTD
# 457  SW14633X000             NTUC Fairprice Co-operative Ltd
# 458  SW14542A000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 459   C02053L000             NTUC Fairprice Co-operative Ltd
# 460   C02033V000             SHENG SIONG SUPERMARKET PTE LTD
# 461  SW06322N000                                OH BENG GUAN
# 462   J96145K000             NTUC Fairprice Co-operative Ltd
# 463  SW16815P000            PHAN NEE INVESTMENTS (S) PTE LTD
# 464   J02018L000            PRIME SUPERMARKET (1996) PTE LTD
# 465   J02010E000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 466  SW11251X000                  AJMAL TRADE MART PTE. LTD.
# 467  SW08740N000               AJMAL TRADING GROUP PTE. LTD.
# 468   J02008P000                                ANG KEN CHUA
# 469  SW09589E000  SHAFEN SUPERMARKET & TRADING (S) PTE. LTD.
# 470  SW15626J000              GINZA FARM SINGAPORE PTE. LTD.
# 471  SW05051J000             SHENG SIONG SUPERMARKET PTE LTD
# 472  SW12O05A000             NTUC Fairprice Co-operative Ltd
# 473  SW08807K000       COLD STORAGE SINGAPORE (1983) PTE LTD
# 474   C02080E000             SHENG SIONG SUPERMARKET PTE LTD
# 475  SW15968N000             NTUC Fairprice Co-operative Ltd
# 476  SW13368A000                           L M MEAT PTE. LTD
# 477  SW12G70J000       COLD STORAGE SINGAPORE (1983) PTE LTD
#
#                          building_name block_house_num level_num unit_num  \
# 0                                   na             982         1        1
# 1          HOUGANG GREEN SHOPPING MALL              21         1       52
# 2                                   na             330         1        1
# 3                        HOUGANG POINT               1         2        1
# 4                                   na              19         1    42401
# 5                     THE SELETAR MALL              33        B2       24
# 6                MUTLI STOREY CAR PARK            542B         2        1
# 7                  FERNVALE RIVERGROVE             473         1        6
# 8                         PPT LODGE 1B               2         1       38
# 9                         PPT LODGE 1A               8        G1        3
# 10                                  na              19        na        0
# 11                                  na             683         1      903
# 12                                  na             682         1      310
# 13                                  na            447A         1        2
# 14                                  na             249        na        0
# 15                                  na             642         1      197
# 16                                  na              53        B2       26
# 17                 ITE COLLEGE CENTRAL               2         1       12
# 18                      GREENWICH, THE               1         1       11
# 19                                  na             712         1     4056
# 20                                  na             525         1     2401
# 21                                  na             215         1      877
# 22                                  na             122         1     1753
# 23               MULTI STOREY CAR PARK            316B         1       11
# 24                                  na             233         1     1168
# 25                                  na             421         1     1161
# 26                                  na             510         1      520
# 27          JUNCTION 8 SHOPPING CENTRE               9        B1       20
# 28                                  na             512         1      524
# 29                                  na             279         1    62/64
# ..                                 ...             ...       ...      ...
# 448                                 na             159         1      178
# 449                          WEST MALL               1        B1        1
# 450                                 na              10         1        8
# 451           JURONG LODGE ONE , BLK A            501A        na        0
# 452                                 na             140         1      351
# 453                                 na             376         1      116
# 454                                 na             142         1      281
# 455                                 na             373         1      248
# 456                                 na              18         1       95
# 457   HomeTeamNS BUKIT BATOK CLUBHOUSE               2         1       10
# 458                             HILLV2               4         2        7
# 459                        #01-256/258             166        na        0
# 460                                 na            154A         1        1
# 461              MULTI STOREY CAR PARK            395A         3       10
# 462               LOT 1 SHOPPERS' MALL              21        B1        3
# 463                                 na             500         1        2
# 464                                 na             253        B1    42650
# 465                                 na             475         1        1
# 466  BLK 1 SCAL DORMITORY (1ST STOREY)              11        na        0
# 467                                 na              1A        na        0
# 468                                 na             410         1      341
# 469                    MURAI LODGE ONE              1B         1        4
# 470             D'' KRANJI FARM RESORT              10         1    10A/B
# 471                                 na             720         1      144
# 472                                 na             502         1       41
# 473            #B1-19 WEST COAST PLAZA             154        na        0
# 474                                 na              61         1       21
# 475                    #01-304/305/306              37        na        0
# 476                   WEST COAST PLAZA             154        B1       14
# 477              KENT VALE ESTATE, NUS             101         1        1
#
#                    street_name postal_code  group
# 0            BUANGKOK CRESCENT      530982      1
# 1            HOUGANG STREET 51      538719      1
# 2            ANCHORVALE STREET      540330     -1
# 3            HOUGANG STREET 91      538692      0
# 4     SERANGOON NORTH AVENUE 5      554913      2
# 5         SENGKANG WEST AVENUE      797653      0
# 6     SERANGOON NORTH AVENUE 3      552542      4
# 7              FERNVALE STREET      790473      2
# 8           SELETAR NORTH LINK      797601     -1
# 9           SELETAR NORTH LINK      797455     -1
# 10      SELETAR WEST FARMWAY 6      798049     -1
# 11            HOUGANG AVENUE 8      530683      1
# 12            HOUGANG AVENUE 4      530682      0
# 13                  JALAN KAYU      791447      0
# 14                  JALAN KAYU      799473     -1
# 15            HOUGANG AVENUE 8      530642     -1
# 16         ANG MO KIO AVENUE 3      569933      0
# 17            ANG MO KIO DRIVE      567720      0
# 18                SELETAR ROAD      807011      1
# 19         ANG MO KIO AVENUE 6      560712      0
# 20        ANG MO KIO AVENUE 10      560525      1
# 21         ANG MO KIO AVENUE 1      560215      0
# 22         ANG MO KIO AVENUE 3      560122      2
# 23        ANG MO KIO STREET 31      563316      1
# 24         ANG MO KIO AVENUE 3      560233      2
# 25        ANG MO KIO AVENUE 10      560421     -1
# 26            BISHAN STREET 13      570510      0
# 27                BISHAN PLACE      579837      0
# 28            BISHAN STREET 13      570512      1
# 29            BISHAN STREET 24      570279      0
# ..                         ...         ...    ...
# 448      BUKIT BATOK STREET 11      650159      3
# 449   BUKIT BATOK CENTRAL LINK      658713      1
# 450        BUKIT BATOK CENTRAL      659958      0
# 451                JURONG ROAD      649698     -1
# 452             TECK WHYE LANE      680140      0
# 453      BUKIT BATOK STREET 31      650376      1
# 454             TECK WHYE LANE      680142      4
# 455      BUKIT BATOK STREET 31      650373      3
# 456             TECK WHYE LANE      680018      2
# 457  BUKIT BATOK WEST AVENUE 7      659003      0
# 458              HILLVIEW RISE      667979      1
# 459  BUKIT BATOK WEST AVENUE 8      650166      0
# 460  BUKIT BATOK WEST AVENUE 8      651154      2
# 461  BUKIT BATOK WEST AVENUE 5      651395     -1
# 462     CHOA CHU KANG AVENUE 4      689812      0
# 463     OLD CHOA CHU KANG ROAD      698928     -1
# 464     CHOA CHU KANG AVENUE 1      680253      4
# 465     CHOA CHU KANG AVENUE 3      680475      1
# 466                JALAN LEKAR      698918     -1
# 467              MURAI FARMWAY      709154     -1
# 468     CHOA CHU KANG AVENUE 3      680410     -1
# 469              MURAI FARMWAY      709155     -1
# 470            NEO TIEW LANE 2      718813     -1
# 471     CLEMENTI WEST STREET 2      120720      2
# 472           WEST COAST DRIVE      120502      0
# 473            WEST COAST ROAD      127371      1
# 474         TEBAN GARDENS ROAD      600061      2
# 475         TEBAN GARDENS ROAD      600037      0
# 476            WEST COAST ROAD      127371     -1
# 477              CLEMENTI ROAD      129787      1
#
# [478 rows x 9 columns]

# %%
df3.groupby('group').size()
# Out:
# group
# -1    174
#  0    133
#  1    111
#  2     42
#  3     10
#  4      8
# dtype: int64

# %% [markdown]
# # convert address to long lat

# %%
# location = df.long_lat[10]
# # x,y = location.point[:2]
# location

# %%
# this is an API , theres a limit on number of requests.

geolocator = Nominatim(user_agent="hello world!")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

df['address'] =  df.block_house_num.astype(str)+" "+df.street_name.astype(str)
df['long_lat'] = df['address'].apply(geocode)
df.head()

# %%
df.to_csv('sg_supermarkets.csv')

# %%
df = pd.read_csv('sg_supermarkets.csv')
df.head()

# %% [markdown]
# # show map

# %%
group_cmap2 = {0:'red',
              1:'green',
              2:'blue',
              3:'yellow',
              4:'cyan',
              -1:'grey'}

# %%
# add marker
def add_marker(x,y,color,cmap=cmap):
    folium.CircleMarker((x,y),popup="",tooltip="",
                        color=color,fill_color=color).add_to(m)

# %%
# draw map
sg_start = (1.3521, 103.8198)
m = folium.Map(location=sg_start,tiles="OpenStreetMap")

error_c = 0
for i in range(0,len(df)-1):
# for i in range(0,50):
    try:
        location = df.long_lat[i]
        x,y = location.point[:2]
        color = group_cmap2[df.group[i]]
        add_marker(x,y,color)
    except:
        error_c +=1
        pass

print(f"number of shops that cannot be plotted {error_c}")
    
m.save('map.html')
m
